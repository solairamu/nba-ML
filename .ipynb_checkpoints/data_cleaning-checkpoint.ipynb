# %%
import pandas as pd

# %%
mvps = pd.read_csv("mvps.csv")

# %%
mvps
# Out:
#      Unnamed: 0 Rank           Player  Age   Tm  First  Pts Won  Pts Max  \
# 0             0    1   Michael Jordan   27  CHI   77.0    891.0      960
# 1             1    2    Magic Johnson   31  LAL   10.0    497.0      960
# 2             2    3   David Robinson   25  SAS    6.0    476.0      960
# 3             3    4  Charles Barkley   27  PHI    2.0    222.0      960
# 4             4    5      Karl Malone   27  UTA    0.0    142.0      960
# ..          ...  ...              ...  ...  ...    ...      ...      ...
# 494           8    9    Stephen Curry   34  GSW    0.0      5.0     1000
# 495           9   10     Jimmy Butler   33  MIA    0.0      3.0     1000
# 496          10   11     De'Aaron Fox   25  SAC    0.0      2.0     1000
# 497          11  12T    Jalen Brunson   26  NYK    0.0      1.0     1000
# 498          12  12T        Ja Morant   23  MEM    0.0      1.0     1000
#
#      Share   G  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  \
# ...

# %%
mvps = mvps[["Player", "Year", "Pts Won", "Pts Max", "Share"]]

# %%
mvps
# Out:
#               Player  Year  Pts Won  Pts Max  Share
# 0     Michael Jordan  1991    891.0      960  0.928
# 1      Magic Johnson  1991    497.0      960  0.518
# 2     David Robinson  1991    476.0      960  0.496
# 3    Charles Barkley  1991    222.0      960  0.231
# 4        Karl Malone  1991    142.0      960  0.148
# ..               ...   ...      ...      ...    ...
# 494    Stephen Curry  2023      5.0     1000  0.005
# 495     Jimmy Butler  2023      3.0     1000  0.003
# 496     De'Aaron Fox  2023      2.0     1000  0.002
# 497    Jalen Brunson  2023      1.0     1000  0.001
# 498        Ja Morant  2023      1.0     1000  0.001
#
# [499 rows x 5 columns]

# %%
players = pd.read_csv("players.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk              Player Pos Age   Tm   G  GS    MP   FG  \
# 0               0    1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3
# 1               1    2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2
# 2               2    3          Mark Acres   C  28  ORL  68   0  19.3  1.6
# 3               3    4       Michael Adams  PG  28  DEN  66  66  35.5  8.5
# 4               4    5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4
# ...           ...  ...                 ...  ..  ..  ...  ..  ..   ...  ...
# 19584         699  535      Thaddeus Young  PF  34  TOR  54   9  14.7  2.0
# 19585         700  536          Trae Young  PG  24  ATL  73  73  34.8  8.2
# 19586         701  537      Omer Yurtseven   C  24  MIA   9   0   9.2  1.8
# 19587         702  538         Cody Zeller   C  30  MIA  15   2  14.5  2.5
# 19588         703  539         Ivica Zubac   C  25  LAC  76  76  28.6  4.3
#
#        ...  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
del players["Unnamed: 0"]
del players["Rk"]

# %%
players
# Out:
#                    Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  \
# 0          Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  .474  ...
# 1      Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  .413  ...
# 2              Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  .509  ...
# 3           Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  .394  ...
# 4            Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  .462  ...
# ...                   ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...
# 19584      Thaddeus Young  PF  34  TOR  54   9  14.7  2.0   3.7  .545  ...
# 19585          Trae Young  PG  24  ATL  73  73  34.8  8.2  19.0  .429  ...
# 19586      Omer Yurtseven   C  24  MIA   9   0   9.2  1.8   3.0  .593  ...
# 19587         Cody Zeller   C  30  MIA  15   2  14.5  2.5   3.9  .627  ...
# 19588         Ivica Zubac   C  25  LAC  76  76  28.6  4.3   6.8  .634  ...
#
#        ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
players["Player"] = players["Player"].str.replace("*", "", regex = False)

# %%
def single_row(df):
    if df.shape[0] == 1:
        return df
    else:
        row = df[df["Tm"] == "TOT"]
        row["Tm"] = df.iloc[-1, :]["Tm"]
        return row
    
players = players.groupby(["Player", "Year"]).apply(single_row)

# %%
players.head(20)
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        Year
# A.C. Green    1991 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#               1992 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#               1993 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#               1994 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 2563      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 3138      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8
#               1998 3725      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5
#               1999 4283      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 4811      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 5330      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0
# ...

# %%
players.index = players.index.droplevel()

# %%
players.index = players.index.droplevel()

# %%
players[players["Player"] == "Greg Anderson"]
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 8     Greg Anderson  PF  26  DEN  68   2  13.6  1.7   4.0  .430  ...  1.4
# 467   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  4.1
# 1412  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  2.4
# 1911  Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  1.2
# 2381  Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  0.6
# 2948  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  1.9
# 3541  Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  0.8
#
#       DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 8     3.3   4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991
# 467   7.4  11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992
# 1412  5.0   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994
# 1911  2.5   3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995
# 2381  1.5   2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996
# 2948  3.5   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997
# ...

# %%
combined = players.merge(mvps, how="outer", on= ["Player", "Year"])

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  BLK  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9  0.7  0.3
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4  1.1  0.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4  1.1  0.5
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9  0.5
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5  0.7  0.4
#
#    TOV   PF   PTS  Year Pts Won Pts Max Share
# 0  1.2  1.4   9.1  1991     NaN     NaN   NaN
# 1  1.4  1.7  13.6  1992     NaN     NaN   NaN
# 2  1.4  1.8  12.8  1993     NaN     NaN   NaN
# 3  1.2  1.7  14.7  1994     NaN     NaN   NaN
# 4  1.4  1.8  11.2  1995     NaN     NaN   NaN
#
# [5 rows x 33 columns]

# %%
combined[combined["Pts Won"] > 0]
# Out:
#               Player    Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  \
# 206     Al Jefferson      C  29  CHA  73  73  35.0   9.6  18.8  .509  ...
# 360    Allen Iverson     PG  21  PHI  76  74  40.1   8.2  19.8  .416  ...
# 362    Allen Iverson     SG  23  PHI  48  48  41.5   9.1  22.0  .412  ...
# 363    Allen Iverson     SG  24  PHI  70  70  40.8  10.4  24.8  .421  ...
# 364    Allen Iverson     SG  25  PHI  71  71  42.0  10.7  25.5  .420  ...
# ...              ...    ...  ..  ...  ..  ..   ...   ...   ...   ...  ...
# 14689   Vince Carter     SF  23  TOR  82  82  38.1   9.6  20.7  .465  ...
# 14690   Vince Carter     SF  24  TOR  75  75  39.7  10.2  22.1  .460  ...
# 14694   Vince Carter  SF-SG  28  NJN  77  76  36.7   9.0  20.0  .452  ...
# 15082       Yao Ming      C  23  HOU  82  82  32.8   6.5  12.5  .522  ...
# 15087       Yao Ming      C  28  HOU  77  77  33.6   7.4  13.4  .548  ...
#
#        AST  STL  BLK  TOV   PF   PTS  Year Pts Won Pts Max  Share
# ...

# %%
combined[["Pts Won", "Pts Max", "Share"]] = combined[["Pts Won", "Pts Max", "Share"]].fillna(0)

# %%
combined
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9
# 1          A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4
# 2          A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4
# 3          A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7
# 4          A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 15231  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  .505  ...  0.5
# 15232  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  .552  ...  0.3
# 15233  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  .442  ...  0.3
# 15234  Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0  .568  ...  0.4
# 15235  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  .542  ...  0.3
#
# ...

# %%
teams = pd.read_csv("teams.csv")

# %%
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  56  26  .683     —  111.5  105.7   5.22  1991
# 1              1  44  38  .537  12.0  105.4  105.6  -0.39  1991
# 2              2  39  43  .476  17.0  103.1  103.3  -0.43  1991
# 3              3  30  52  .366  26.0  101.4  106.4  -4.84  1991
# 4              4  26  56  .317  30.0  102.9  107.5  -4.53  1991
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1098          13  51  31  .622     —  116.9  113.0   3.60  2023
# 1099          14  42  40  .512   9.0  114.4  112.5   1.63  2023
# 1100          15  38  44  .463  13.0  114.2  114.1  -0.14  2023
# 1101          16  22  60  .268  29.0  110.7  118.6  -7.62  2023
# 1102          17  22  60  .268  29.0  113.0  123.1  -9.82  2023
#
#                            Team
# 0               Boston Celtics*
# 1           Philadelphia 76ers*
# 2              New York Knicks*
# 3            Washington Bullets
# ...

# %%
teams = teams[~teams["W"].str.contains("Division")]

# %%
teams["Team"] = teams["Team"].str.replace("*", "", regex=False)
# Out:
# /var/folders/_p/r9t1b6hj7vg3m_0qb667zd7w0000gn/T/ipykernel_20640/3338997264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teams["Team"] = teams["Team"].str.replace("*", "", regex=False)

# %%
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  56  26  .683     —  111.5  105.7   5.22  1991
# 1              1  44  38  .537  12.0  105.4  105.6  -0.39  1991
# 2              2  39  43  .476  17.0  103.1  103.3  -0.43  1991
# 3              3  30  52  .366  26.0  101.4  106.4  -4.84  1991
# 4              4  26  56  .317  30.0  102.9  107.5  -4.53  1991
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1098          13  51  31  .622     —  116.9  113.0   3.60  2023
# 1099          14  42  40  .512   9.0  114.4  112.5   1.63  2023
# 1100          15  38  44  .463  13.0  114.2  114.1  -0.14  2023
# 1101          16  22  60  .268  29.0  110.7  118.6  -7.62  2023
# 1102          17  22  60  .268  29.0  113.0  123.1  -9.82  2023
#
#                           Team
# 0               Boston Celtics
# 1           Philadelphia 76ers
# 2              New York Knicks
# 3           Washington Bullets
# 4              New Jersey Nets
# ...

# %%
teams["Team"] = teams["Team"].str.replace("\(\d+\)", "", regex=True)
# Out:
# /var/folders/_p/r9t1b6hj7vg3m_0qb667zd7w0000gn/T/ipykernel_20640/1612970114.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teams["Team"] = teams["Team"].str.replace("\(\d+\)", "", regex=True)

# %%
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  56  26  .683     —  111.5  105.7   5.22  1991
# 1              1  44  38  .537  12.0  105.4  105.6  -0.39  1991
# 2              2  39  43  .476  17.0  103.1  103.3  -0.43  1991
# 3              3  30  52  .366  26.0  101.4  106.4  -4.84  1991
# 4              4  26  56  .317  30.0  102.9  107.5  -4.53  1991
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1098          13  51  31  .622     —  116.9  113.0   3.60  2023
# 1099          14  42  40  .512   9.0  114.4  112.5   1.63  2023
# 1100          15  38  44  .463  13.0  114.2  114.1  -0.14  2023
# 1101          16  22  60  .268  29.0  110.7  118.6  -7.62  2023
# 1102          17  22  60  .268  29.0  113.0  123.1  -9.82  2023
#
#                        Team
# 0            Boston Celtics
# 1        Philadelphia 76ers
# 2           New York Knicks
# 3        Washington Bullets
# 4           New Jersey Nets
# ...

# %%
nicknames = {}

with open("nicknames.csv") as f:
    lines = f.readlines()
    for line in lines[1:]:
        abbrev, name = line.replace("\n", "").split(",")
        nicknames[abbrev] = name

# %%
combined["Team"] = combined["Tm"].map(nicknames)

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7  0.3  1.2
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1  0.4  1.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1  0.5  1.4
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9  0.5  1.2
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7  0.4  1.4
#
#     PF   PTS  Year Pts Won Pts Max Share                Team
# 0  1.4   9.1  1991     0.0     0.0   0.0  Los Angeles Lakers
# 1  1.7  13.6  1992     0.0     0.0   0.0  Los Angeles Lakers
# 2  1.8  12.8  1993     0.0     0.0   0.0  Los Angeles Lakers
# 3  1.7  14.7  1994     0.0     0.0   0.0        Phoenix Suns
# 4  1.8  11.2  1995     0.0     0.0   0.0        Phoenix Suns
#
# [5 rows x 34 columns]

# %%
stats = combined.merge(teams, how="outer", on=["Team", "Year"])

# %%
stats
# Out:
#                Player  Pos  Age   Tm    G   GS    MP   FG   FGA   FG%  ...  \
# 0          A.C. Green   PF   27  LAL   82   21  26.4  3.1   6.6  .476  ...
# 1         Byron Scott   SG   29  LAL   82   82  32.1  6.1  12.8  .477  ...
# 2      Elden Campbell   PF   22  LAL   52    0   7.3  1.1   2.4  .455  ...
# 3       Irving Thomas   PF   25  LAL   26    0   4.2  0.7   1.9  .340  ...
# 4        James Worthy   SF   29  LAL   78   74  38.6  9.2  18.7  .492  ...
# ...               ...  ...  ...  ...  ...  ...   ...  ...   ...   ...  ...
# 15261             NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
# 15262             NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
# 15263             NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
# 15264             NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
# 15265             NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
#
# ...

# %%
stats = stats.drop(stats[stats['Year'] == 2023].index)

# %%
stats
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ... Share  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...   0.0
# 1         Byron Scott  SG  29  LAL  82  82  32.1  6.1  12.8  .477  ...   0.0
# 2      Elden Campbell  PF  22  LAL  52   0   7.3  1.1   2.4  .455  ...   0.0
# 3       Irving Thomas  PF  25  LAL  26   0   4.2  0.7   1.9  .340  ...   0.0
# 4        James Worthy  SF  29  LAL  78  74  38.6  9.2  18.7  .492  ...   0.0
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...   ...
# 15231   Spencer Hawes  PF  28  MIL  54   1  14.8  2.5   5.1  .484  ...   0.0
# 15232     Steve Novak  PF  33  MIL   8   0   2.8  0.3   0.9  .286  ...   0.0
# 15233  Terrence Jones  PF  25  MIL  54  12  23.5  4.3   9.1  .470  ...   0.0
# 15234      Thon Maker   C  19  MIL  57  34   9.9  1.5   3.2  .459  ...   0.0
# 15235      Tony Snell  SG  25  MIL  80  80  29.2  3.1   6.8  .455  ...   0.0
#
# ...

# %%
del stats["Unnamed: 0"]

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age         object
# Tm          object
# G           object
# GS          object
# MP          object
# FG          object
# FGA         object
# FG%         object
# 3P          object
# 3PA         object
# 3P%         object
# 2P          object
# 2PA         object
# 2P%         object
# eFG%        object
# FT          object
# FTA         object
# FT%         object
# ORB         object
# DRB         object
# TRB         object
# AST         object
# STL         object
# BLK         object
# TOV         object
# PF          object
# PTS         object
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W           object
# L           object
# W/L%        object
# GB          object
# PS/G        object
# PA/G        object
# SRS         object
# dtype: object

# %%
stats = stats.apply(pd.to_numeric, errors="ignore")

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats["GB"].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '—', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '25.0', '8.0',
#        '19.0', '1.0', '13.0', '17.0', '3.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '31.0', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0',
#        '33.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5'],
#       dtype=object)

# %%
stats["GB"] = stats["GB"].str.replace("—", "0")

# %%
stats["GB"].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '0', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '25.0', '8.0',
#        '19.0', '1.0', '13.0', '17.0', '3.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '31.0', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0',
#        '33.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5'],
#       dtype=object)

# %%
stats["GB"] = pd.to_numeric(stats["GB"])

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats.to_csv("player_mvp_stats.csv")

# %%
highest_scoring = stats[stats["G"] > 70].sort_values("PTS", ascending=False).head(10)

# %%
highest_scoring
# Out:
#                   Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 10432       James Harden  PG   29  HOU  78  78  36.8  10.8  24.5  0.442  ...
# 1186         Kobe Bryant  SG   27  LAL  80  80  41.0  12.2  27.2  0.450  ...
# 4874       Allen Iverson  PG   30  PHI  72  72  43.1  11.3  25.3  0.447  ...
# 10751     Michael Jordan  SG   29  CHI  78  78  39.3  12.7  25.7  0.495  ...
# 7455       Tracy McGrady  SG   23  ORL  75  74  39.4  11.1  24.2  0.457  ...
# 6884        Kevin Durant  SF   25  OKC  81  81  38.5  10.5  20.8  0.503  ...
# 6936   Russell Westbrook  PG   28  OKC  81  81  34.6  10.2  24.0  0.425  ...
# 1200         Kobe Bryant  SG   28  LAL  77  77  40.8  10.6  22.8  0.463  ...
# 10725     Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539  ...
# 3576        LeBron James  SF   21  CLE  79  79  42.5  11.1  23.1  0.480  ...
#
#        Pts Max  Share                   Team   W   L   W/L%    GB   PS/G  \
# ...

# %%
highest_scoring.plot.bar("Player", "PTS")
# Out:
# <AxesSubplot: xlabel='Player'>

# %%
top_scorer_year = stats.groupby("Year").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))

# %%
top_scorer_year
# Out:
#                        Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# Year
# 1991 10725     Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539
# 1992 10738     Michael Jordan  SG   28  CHI  80  80  38.8  11.8  22.7  0.519
# 1993 10751     Michael Jordan  SG   29  CHI  78  78  39.3  12.7  25.7  0.495
# 1994 9445      David Robinson   C   28  SAS  80  80  40.5  10.5  20.7  0.507
# 1995 7932    Shaquille O'Neal   C   22  ORL  79  79  37.0  11.8  20.2  0.583
# 1996 11346     Michael Jordan  SG   32  CHI  82  82  37.7  11.2  22.6  0.495
# 1997 11360     Michael Jordan  SG   33  CHI  82  82  37.9  11.2  23.1  0.486
# 1998 11374     Michael Jordan  SG   34  CHI  82  82  38.8  10.7  23.1  0.465
# 1999 1072       Allen Iverson  SG   23  PHI  48  48  41.5   9.1  22.0  0.412
# 2000 143     Shaquille O'Neal   C   27  LAL  79  79  40.0  12.1  21.1  0.574
# 2001 1103       Allen Iverson  SG   25  PHI  71  71  42.0  10.7  25.5  0.420
# ...

# %%
top_scorer_year.plot.bar("Year", "PTS")
# Out:
# <AxesSubplot: xlabel='Year'>
